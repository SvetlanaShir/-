# %% [markdown]
# # Введение в анализ данных
# ## НИУ ВШЭ, 2020-2021 учебный год
#
# ### Домашнее задание №8

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, mean_squared_error

# %% [markdown]
# ## Градиентный бустинг своими руками (2 + 2* баллов)
#
# Реализуйте алгоритм градиентного бустинга для регрессии. Напомним основные формулы.
#
# Обозначим текущую композицию на $N-1$ шаге за $a_{N - 1}(x_i)$. Следующий базовый алгоритм $b_N(x_i)$ обучается на ответах $-\frac{\partial L(y_i, z)}{\partial z}\Bigl|_{z = a_{N - 1}(x_i)}$, где $L(y_i, z)$ — значение функции потерь на объекте при правильном ответе $y_i$ и предсказании $z$. Композиция на следующем шаге получается следующим образом:
#
# $$
# a_N(x_i) = a_{N-1}(x_i) + \nu\gamma_Nb_N(x_i)
# $$
#
# Здесь $\nu$ — гиперпараметр learning rate, $\gamma_N$ — оптимальный вес, настраиваемый на каждом шаге алгоритма, который можно найти по следующей формуле (обратите внимание на отсутствие $\nu$):
#
# $$
# \gamma_N = \mathrm{arg}\min_\gamma \frac{1}{\ell}\sum\limits_{i=1}^{\ell}L\left(y_i, a_{N - 1}(x_i) + \gamma b_N(x_i)\right)
# $$
#
# Можете принять $\gamma_N = 1$ для каждого $N$. Реализуйте нахождение оптимального $\gamma_N$ на каждом шаге, чтобы получить ещё 1 балл.
#
# В качестве функции потерь возьмите MSE.
#
# *Примечание. Вы можете использовать `DecisionTree` из `sklearn` и методы оптимизации из различных библиотек.*

# %%
# это может помочь вам для поиска оптимальных gamma
from scipy import optimize

# %%
class GradientBoosting:
    def __init__(self, n_estimators, max_depth, learning_rate=0.1):
        """
        PARAMETERS:
        n_estimators - number of trees in the ensemble
        max_depth - maximum depth of a tree
        learning_rate - coefficient by which new algorithm result is multiplied
        """
        self.n_estimators = n_estimators
        self.max_depth = max_depth
        self.learning_rate = learning_rate
        self.gamma=1
        
    def fit(self, x, y):
        """
        INPUT:
        x - np.array of shape (k, d)
        y - np.array of shape (k,)
        """
        # Здесь нам нужно проитерироваться по n_estimators и обучить
        # соответствующее количество деревьев с помощью _fit_predict_tree(),
        # правильно обновляя y_new
        # Деревья нужно где-то сохранить, чтобы затем использовать в predict()
        # your code here
        self.trees = []
        y_new = y
        for i in range(self.n_estimators):
            self.trees.append(DecisionTreeRegressor(max_depth = self.max_depth))
            y_tree = self._fit_predict_tree(x, y_new)
            y_new = y_new - y_tree

    def _fit_predict_tree(self, x, y):
        # Обучаем дерево и возвращаем его предикшн
        tree = self.trees[-1]
        tree.fit(x, y)
        fun = lambda t: mean_squared_error(y, t * tree.predict(x))
        self.gamma = optimize.minimize_scalar(fun)['x']
        return self.gamma * self.learning_rate * tree.predict(x)
        
    def predict(self, x):
        """
        INPUT:
        x - np.array of shape (m, d)
        OUTPUT:
        y_pred - np.array of shape (m,)
        """
        # Используем сохранённые деревья для расчёта агрегированного предикшна
        y_pred = np.zeros(x.shape[0])
        for i in range(self.n_estimators):
            tree = self.trees[i]
            y_tree = self.gamma * self.learning_rate * tree.predict(x)
            y_pred += y_tree
        return y_pred

# %% [markdown]
# Проверьте вашу реализацию на Boston dataset. Подберите оптимальные гиперпараметры, чтобы победить RandomForestRegressor как в обычном случае, так и при нахождении оптимального шага **(не меняйте параметры сида)**. При необходимости воспользуйтесь GridSearch. За это вы получите ещё 1 балл.

# %%
boston = load_boston()
X = boston.data
y = boston.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=13)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(max_features=4, n_estimators=640, random_state=19052019)

rf.fit(X_train, y_train)
mean_squared_error(y_test, rf.predict(X_test))
# Out:
# 9.63198271791959

# %%
np.random.seed(19052019)
gb = GradientBoosting(400, 6, 0.03580000929949099)
gb.fit(X_train, y_train)
y_pred = gb.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 9.619836009722205

# %% [markdown]
# Для удобства проверяющего укажите, пожалуйста, реализовали ли вы нахождение оптимального шага?
#
# - Да

# %% [markdown]
# ## Прогнозируем задержки самолётов (2 балла)

# %% [markdown]
# Поработаем с задачей про задержки самолётов. На основании доступных данных о рейсе вам нужно определить, будет ли он задержан на 15 минут.
# Воспользуйтесь любыми методами градиентного бустинга {XGboost, catboost, LightGBM} и GridSearch для достижения результата. Получите 1 балл за преодоление порога roc_auc_score 0.72 и ещё 1 балл за преодоление порога 0.74.

# %%
train = pd.read_csv('https://raw.githubusercontent.com/PersDep/data-mining-intro-2021/main/hw08-boosting-clustering/flight_delays_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/PersDep/data-mining-intro-2021/main/hw08-boosting-clustering/flight_delays_test.csv')

# %%
train.head()
# Out:
#   Month DayofMonth DayOfWeek  DepTime UniqueCarrier Origin Dest  Distance  \
# 0   c-8       c-21       c-7     1934            AA    ATL  DFW       732
# 1   c-4       c-20       c-3     1548            US    PIT  MCO       834
# 2   c-9        c-2       c-5     1422            XE    RDU  CLE       416
# 3  c-11       c-25       c-6     1015            OO    DEN  MEM       872
# 4  c-10        c-7       c-6     1828            WN    MDW  OMA       423
#
#   dep_delayed_15min
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 Y

# %%
# Референс

from xgboost.sklearn import XGBClassifier

X_train = train[['Distance', 'DepTime']].values
y_train = train['dep_delayed_15min'].map({'Y': 1, 'N': 0}).values
X_test = test[['Distance', 'DepTime']].values
X_train_part, X_valid, y_train_part, y_valid = train_test_split(X_train, y_train, test_size=0.3)

xgb_model = XGBClassifier()
xgb_model.fit(X_train_part, y_train_part)
roc_auc_score(y_valid, xgb_model.predict_proba(X_valid)[:, 1])
# Out:
# C:\Users\lenas\anaconda3\anaconda33\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.7015741427151587

# %%
from catboost import CatBoostClassifier

X_train = train.drop(columns=['dep_delayed_15min'])
y_train = train['dep_delayed_15min'].map({'Y': 1, 'N': 0}).values
X_test = test
X_train_part, X_valid, y_train_part, y_valid = train_test_split(X_train, y_train, test_size=0.3)

cat_model = CatBoostClassifier(cat_features = ['Month', 'DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'Origin', 'Dest'])
cat_model.fit(X_train_part, y_train_part)
# Out:
# Learning rate set to 0.063211
# 0:	learn: 0.6606730	total: 376ms	remaining: 6m 15s
# 1:	learn: 0.6333274	total: 498ms	remaining: 4m 8s
# 2:	learn: 0.6087510	total: 630ms	remaining: 3m 29s
# 3:	learn: 0.5890346	total: 702ms	remaining: 2m 54s
# 4:	learn: 0.5722791	total: 765ms	remaining: 2m 32s
# 5:	learn: 0.5556376	total: 901ms	remaining: 2m 29s
# 6:	learn: 0.5421690	total: 997ms	remaining: 2m 21s
# 7:	learn: 0.5294192	total: 1.12s	remaining: 2m 19s
# 8:	learn: 0.5199410	total: 1.18s	remaining: 2m 9s
# 9:	learn: 0.5107531	total: 1.31s	remaining: 2m 9s
# 10:	learn: 0.5032507	total: 1.44s	remaining: 2m 9s
# 11:	learn: 0.4968468	total: 1.51s	remaining: 2m 4s
# 12:	learn: 0.4909254	total: 1.66s	remaining: 2m 5s
# 13:	learn: 0.4849591	total: 1.82s	remaining: 2m 8s
# 14:	learn: 0.4817900	total: 1.85s	remaining: 2m 1s
# 15:	learn: 0.4771753	total: 1.99s	remaining: 2m 2s
# 16:	learn: 0.4728848	total: 2.14s	remaining: 2m 3s
# 17:	learn: 0.4700037	total: 2.27s	remaining: 2m 3s
# 18:	learn: 0.4669753	total: 2.42s	remaining: 2m 5s
# 19:	learn: 0.4639763	total: 2.53s	remaining: 2m 4s
# 20:	learn: 0.4616939	total: 2.65s	remaining: 2m 3s
# 21:	learn: 0.4589918	total: 2.79s	remaining: 2m 3s
# 22:	learn: 0.4571998	total: 2.92s	remaining: 2m 4s
# 23:	learn: 0.4556031	total: 3.06s	remaining: 2m 4s
# 24:	learn: 0.4534584	total: 3.21s	remaining: 2m 5s
# 25:	learn: 0.4522781	total: 3.37s	remaining: 2m 6s
# 26:	learn: 0.4505046	total: 3.52s	remaining: 2m 6s
# 27:	learn: 0.4493045	total: 3.69s	remaining: 2m 8s
# 28:	learn: 0.4481559	total: 3.83s	remaining: 2m 8s
# 29:	learn: 0.4468337	total: 3.98s	remaining: 2m 8s
# 30:	learn: 0.4456019	total: 4.16s	remaining: 2m 10s
# 31:	learn: 0.4446960	total: 4.32s	remaining: 2m 10s
# 32:	learn: 0.4439347	total: 4.51s	remaining: 2m 12s
# 33:	learn: 0.4431755	total: 4.65s	remaining: 2m 12s
# 34:	learn: 0.4423618	total: 4.81s	remaining: 2m 12s
# 35:	learn: 0.4418165	total: 4.99s	remaining: 2m 13s
# 36:	learn: 0.4413145	total: 5.07s	remaining: 2m 11s
# 37:	learn: 0.4407765	total: 5.24s	remaining: 2m 12s
# 38:	learn: 0.4402039	total: 5.39s	remaining: 2m 12s
# 39:	learn: 0.4395563	total: 5.53s	remaining: 2m 12s
# 40:	learn: 0.4393603	total: 5.58s	remaining: 2m 10s
# 41:	learn: 0.4387157	total: 5.74s	remaining: 2m 10s
# 42:	learn: 0.4382918	total: 5.93s	remaining: 2m 12s
# 43:	learn: 0.4376738	total: 6.09s	remaining: 2m 12s
# 44:	learn: 0.4372093	total: 6.24s	remaining: 2m 12s
# 45:	learn: 0.4366521	total: 6.4s	remaining: 2m 12s
# 46:	learn: 0.4362759	total: 6.58s	remaining: 2m 13s
# 47:	learn: 0.4359747	total: 6.76s	remaining: 2m 14s
# 48:	learn: 0.4357116	total: 6.91s	remaining: 2m 14s
# 49:	learn: 0.4352633	total: 7.04s	remaining: 2m 13s
# 50:	learn: 0.4347436	total: 7.23s	remaining: 2m 14s
# 51:	learn: 0.4345198	total: 7.38s	remaining: 2m 14s
# 52:	learn: 0.4342547	total: 7.54s	remaining: 2m 14s
# 53:	learn: 0.4339450	total: 7.74s	remaining: 2m 15s
# 54:	learn: 0.4337646	total: 7.91s	remaining: 2m 15s
# 55:	learn: 0.4335218	total: 8.1s	remaining: 2m 16s
# 56:	learn: 0.4332224	total: 8.28s	remaining: 2m 17s
# 57:	learn: 0.4329430	total: 8.48s	remaining: 2m 17s
# 58:	learn: 0.4327256	total: 8.67s	remaining: 2m 18s
# 59:	learn: 0.4324359	total: 8.86s	remaining: 2m 18s
# 60:	learn: 0.4320420	total: 9.01s	remaining: 2m 18s
# 61:	learn: 0.4318413	total: 9.15s	remaining: 2m 18s
# 62:	learn: 0.4315185	total: 9.32s	remaining: 2m 18s
# 63:	learn: 0.4313336	total: 9.48s	remaining: 2m 18s
# 64:	learn: 0.4308478	total: 9.65s	remaining: 2m 18s
# 65:	learn: 0.4306388	total: 9.83s	remaining: 2m 19s
# 66:	learn: 0.4303043	total: 9.98s	remaining: 2m 18s
# 67:	learn: 0.4300846	total: 10.2s	remaining: 2m 19s
# 68:	learn: 0.4299037	total: 10.4s	remaining: 2m 19s
# 69:	learn: 0.4296942	total: 10.6s	remaining: 2m 20s
# 70:	learn: 0.4295241	total: 10.7s	remaining: 2m 20s
# 71:	learn: 0.4292248	total: 10.9s	remaining: 2m 20s
# 72:	learn: 0.4290747	total: 11s	remaining: 2m 19s
# 73:	learn: 0.4289475	total: 11.1s	remaining: 2m 19s
# 74:	learn: 0.4287744	total: 11.3s	remaining: 2m 19s
# 75:	learn: 0.4285624	total: 11.4s	remaining: 2m 18s
# 76:	learn: 0.4284355	total: 11.5s	remaining: 2m 18s
# 77:	learn: 0.4282724	total: 11.6s	remaining: 2m 17s
# 78:	learn: 0.4281822	total: 11.8s	remaining: 2m 17s
# 79:	learn: 0.4281157	total: 11.9s	remaining: 2m 16s
# 80:	learn: 0.4280953	total: 12s	remaining: 2m 15s
# 81:	learn: 0.4279362	total: 12.1s	remaining: 2m 15s
# 82:	learn: 0.4278420	total: 12.3s	remaining: 2m 15s
# 83:	learn: 0.4277838	total: 12.4s	remaining: 2m 15s
# 84:	learn: 0.4275573	total: 12.5s	remaining: 2m 14s
# 85:	learn: 0.4273865	total: 12.7s	remaining: 2m 14s
# 86:	learn: 0.4272590	total: 12.8s	remaining: 2m 14s
# 87:	learn: 0.4271726	total: 13s	remaining: 2m 14s
# 88:	learn: 0.4269991	total: 13.1s	remaining: 2m 14s
# 89:	learn: 0.4268471	total: 13.3s	remaining: 2m 14s
# 90:	learn: 0.4266419	total: 13.4s	remaining: 2m 14s
# 91:	learn: 0.4265031	total: 13.6s	remaining: 2m 14s
# 92:	learn: 0.4263814	total: 13.7s	remaining: 2m 14s
# 93:	learn: 0.4262556	total: 13.9s	remaining: 2m 14s
# 94:	learn: 0.4261179	total: 14.1s	remaining: 2m 14s
# 95:	learn: 0.4259766	total: 14.3s	remaining: 2m 14s
# 96:	learn: 0.4258198	total: 14.4s	remaining: 2m 14s
# 97:	learn: 0.4256378	total: 14.6s	remaining: 2m 14s
# 98:	learn: 0.4254993	total: 14.8s	remaining: 2m 14s
# 99:	learn: 0.4253843	total: 14.9s	remaining: 2m 14s
# 100:	learn: 0.4252714	total: 15.1s	remaining: 2m 14s
# 101:	learn: 0.4250954	total: 15.2s	remaining: 2m 14s
# 102:	learn: 0.4249612	total: 15.4s	remaining: 2m 14s
# 103:	learn: 0.4248305	total: 15.6s	remaining: 2m 14s
# 104:	learn: 0.4247579	total: 15.7s	remaining: 2m 14s
# 105:	learn: 0.4246975	total: 15.9s	remaining: 2m 14s
# 106:	learn: 0.4246272	total: 16.1s	remaining: 2m 14s
# 107:	learn: 0.4244624	total: 16.3s	remaining: 2m 14s
# 108:	learn: 0.4243670	total: 16.4s	remaining: 2m 14s
# 109:	learn: 0.4242611	total: 16.6s	remaining: 2m 14s
# 110:	learn: 0.4242062	total: 16.7s	remaining: 2m 13s
# 111:	learn: 0.4240795	total: 16.8s	remaining: 2m 13s
# 112:	learn: 0.4239259	total: 17s	remaining: 2m 13s
# 113:	learn: 0.4238569	total: 17.1s	remaining: 2m 13s
# 114:	learn: 0.4237686	total: 17.3s	remaining: 2m 13s
# 115:	learn: 0.4236641	total: 17.5s	remaining: 2m 13s
# 116:	learn: 0.4236023	total: 17.6s	remaining: 2m 13s
# 117:	learn: 0.4235779	total: 17.8s	remaining: 2m 13s
# 118:	learn: 0.4235720	total: 17.9s	remaining: 2m 12s
# 119:	learn: 0.4234490	total: 18.2s	remaining: 2m 13s
# 120:	learn: 0.4233541	total: 18.4s	remaining: 2m 13s
# 121:	learn: 0.4232354	total: 18.5s	remaining: 2m 13s
# 122:	learn: 0.4231311	total: 18.7s	remaining: 2m 13s
# 123:	learn: 0.4230929	total: 18.8s	remaining: 2m 12s
# 124:	learn: 0.4230287	total: 19s	remaining: 2m 12s
# 125:	learn: 0.4230030	total: 19s	remaining: 2m 11s
# 126:	learn: 0.4229061	total: 19.1s	remaining: 2m 11s
# 127:	learn: 0.4228205	total: 19.3s	remaining: 2m 11s
# 128:	learn: 0.4227103	total: 19.4s	remaining: 2m 11s
# 129:	learn: 0.4226434	total: 19.6s	remaining: 2m 10s
# 130:	learn: 0.4224811	total: 19.7s	remaining: 2m 10s
# 131:	learn: 0.4224121	total: 19.8s	remaining: 2m 10s
# 132:	learn: 0.4222903	total: 20s	remaining: 2m 10s
# 133:	learn: 0.4222202	total: 20.1s	remaining: 2m 9s
# 134:	learn: 0.4221484	total: 20.2s	remaining: 2m 9s
# 135:	learn: 0.4220081	total: 20.4s	remaining: 2m 9s
# 136:	learn: 0.4218168	total: 20.6s	remaining: 2m 9s
# 137:	learn: 0.4217120	total: 20.7s	remaining: 2m 9s
# 138:	learn: 0.4216121	total: 20.8s	remaining: 2m 9s
# 139:	learn: 0.4215516	total: 21s	remaining: 2m 9s
# 140:	learn: 0.4214618	total: 21.1s	remaining: 2m 8s
# 141:	learn: 0.4213866	total: 21.3s	remaining: 2m 8s
# 142:	learn: 0.4213786	total: 21.3s	remaining: 2m 7s
# 143:	learn: 0.4212868	total: 21.5s	remaining: 2m 7s
# 144:	learn: 0.4212235	total: 21.6s	remaining: 2m 7s
# 145:	learn: 0.4211706	total: 21.8s	remaining: 2m 7s
# 146:	learn: 0.4211114	total: 21.9s	remaining: 2m 7s
# 147:	learn: 0.4210034	total: 22.1s	remaining: 2m 7s
# 148:	learn: 0.4209465	total: 22.2s	remaining: 2m 6s
# 149:	learn: 0.4209022	total: 22.4s	remaining: 2m 6s
# 150:	learn: 0.4208776	total: 22.5s	remaining: 2m 6s
# 151:	learn: 0.4208093	total: 22.6s	remaining: 2m 6s
# 152:	learn: 0.4207357	total: 22.8s	remaining: 2m 5s
# 153:	learn: 0.4206883	total: 22.9s	remaining: 2m 5s
# 154:	learn: 0.4206420	total: 23.1s	remaining: 2m 5s
# 155:	learn: 0.4205716	total: 23.3s	remaining: 2m 5s
# 156:	learn: 0.4205139	total: 23.4s	remaining: 2m 5s
# 157:	learn: 0.4204519	total: 23.5s	remaining: 2m 5s
# 158:	learn: 0.4204036	total: 23.7s	remaining: 2m 5s
# 159:	learn: 0.4203365	total: 23.8s	remaining: 2m 5s
# 160:	learn: 0.4203097	total: 24s	remaining: 2m 5s
# 161:	learn: 0.4202368	total: 24.1s	remaining: 2m 4s
# 162:	learn: 0.4201750	total: 24.3s	remaining: 2m 4s
# 163:	learn: 0.4201302	total: 24.4s	remaining: 2m 4s
# 164:	learn: 0.4200597	total: 24.6s	remaining: 2m 4s
# 165:	learn: 0.4199917	total: 24.7s	remaining: 2m 4s
# 166:	learn: 0.4199617	total: 24.9s	remaining: 2m 4s
# 167:	learn: 0.4198859	total: 25s	remaining: 2m 3s
# 168:	learn: 0.4197995	total: 25.1s	remaining: 2m 3s
# 169:	learn: 0.4197247	total: 25.3s	remaining: 2m 3s
# 170:	learn: 0.4196458	total: 25.4s	remaining: 2m 3s
# 171:	learn: 0.4195917	total: 25.5s	remaining: 2m 2s
# 172:	learn: 0.4194922	total: 25.7s	remaining: 2m 2s
# 173:	learn: 0.4194187	total: 25.8s	remaining: 2m 2s
# 174:	learn: 0.4192953	total: 26s	remaining: 2m 2s
# 175:	learn: 0.4192162	total: 26.1s	remaining: 2m 2s
# 176:	learn: 0.4191771	total: 26.2s	remaining: 2m 2s
# 177:	learn: 0.4191376	total: 26.4s	remaining: 2m 2s
# 178:	learn: 0.4190464	total: 26.6s	remaining: 2m 2s
# 179:	learn: 0.4189526	total: 26.7s	remaining: 2m 1s
# 180:	learn: 0.4189193	total: 26.9s	remaining: 2m 1s
# 181:	learn: 0.4188585	total: 27s	remaining: 2m 1s
# 182:	learn: 0.4187758	total: 27.2s	remaining: 2m 1s
# 183:	learn: 0.4186597	total: 27.4s	remaining: 2m 1s
# 184:	learn: 0.4186002	total: 27.6s	remaining: 2m 1s
# 185:	learn: 0.4184780	total: 27.8s	remaining: 2m 1s
# 186:	learn: 0.4184381	total: 27.9s	remaining: 2m 1s
# 187:	learn: 0.4183938	total: 28.1s	remaining: 2m 1s
# 188:	learn: 0.4183221	total: 28.2s	remaining: 2m 1s
# 189:	learn: 0.4181940	total: 28.4s	remaining: 2m
# 190:	learn: 0.4181049	total: 28.5s	remaining: 2m
# 191:	learn: 0.4180615	total: 28.7s	remaining: 2m
# 192:	learn: 0.4180270	total: 28.8s	remaining: 2m
# 193:	learn: 0.4179488	total: 29s	remaining: 2m
# 194:	learn: 0.4178615	total: 29.1s	remaining: 2m
# 195:	learn: 0.4178041	total: 29.3s	remaining: 1m 59s
# 196:	learn: 0.4177276	total: 29.4s	remaining: 1m 59s
# 197:	learn: 0.4176519	total: 29.5s	remaining: 1m 59s
# 198:	learn: 0.4175322	total: 29.7s	remaining: 1m 59s
# 199:	learn: 0.4174827	total: 29.8s	remaining: 1m 59s
# 200:	learn: 0.4174246	total: 30s	remaining: 1m 59s
# 201:	learn: 0.4173707	total: 30.1s	remaining: 1m 58s
# 202:	learn: 0.4172886	total: 30.3s	remaining: 1m 58s
# 203:	learn: 0.4172072	total: 30.4s	remaining: 1m 58s
# 204:	learn: 0.4171578	total: 30.6s	remaining: 1m 58s
# 205:	learn: 0.4170841	total: 30.7s	remaining: 1m 58s
# 206:	learn: 0.4170505	total: 30.8s	remaining: 1m 58s
# 207:	learn: 0.4169668	total: 31s	remaining: 1m 57s
# 208:	learn: 0.4169441	total: 31.1s	remaining: 1m 57s
# 209:	learn: 0.4169097	total: 31.3s	remaining: 1m 57s
# 210:	learn: 0.4168478	total: 31.4s	remaining: 1m 57s
# 211:	learn: 0.4167101	total: 31.6s	remaining: 1m 57s
# 212:	learn: 0.4166467	total: 31.8s	remaining: 1m 57s
# 213:	learn: 0.4165589	total: 31.9s	remaining: 1m 57s
# 214:	learn: 0.4164560	total: 32.1s	remaining: 1m 57s
# 215:	learn: 0.4163987	total: 32.3s	remaining: 1m 57s
# 216:	learn: 0.4163618	total: 32.4s	remaining: 1m 57s
# 217:	learn: 0.4163144	total: 32.6s	remaining: 1m 56s
# 218:	learn: 0.4162496	total: 32.7s	remaining: 1m 56s
# 219:	learn: 0.4161941	total: 32.9s	remaining: 1m 56s
# 220:	learn: 0.4161478	total: 33s	remaining: 1m 56s
# 221:	learn: 0.4161109	total: 33.2s	remaining: 1m 56s
# 222:	learn: 0.4160625	total: 33.3s	remaining: 1m 56s
# 223:	learn: 0.4160146	total: 33.4s	remaining: 1m 55s
# 224:	learn: 0.4159378	total: 33.5s	remaining: 1m 55s
# 225:	learn: 0.4158546	total: 33.7s	remaining: 1m 55s
# 226:	learn: 0.4157836	total: 33.8s	remaining: 1m 55s
# 227:	learn: 0.4156979	total: 34s	remaining: 1m 55s
# 228:	learn: 0.4156539	total: 34.1s	remaining: 1m 54s
# 229:	learn: 0.4156055	total: 34.3s	remaining: 1m 54s
# 230:	learn: 0.4155911	total: 34.4s	remaining: 1m 54s
# 231:	learn: 0.4155009	total: 34.5s	remaining: 1m 54s
# 232:	learn: 0.4154475	total: 34.6s	remaining: 1m 54s
# 233:	learn: 0.4153846	total: 34.8s	remaining: 1m 53s
# 234:	learn: 0.4153708	total: 34.9s	remaining: 1m 53s
# 235:	learn: 0.4152872	total: 35.1s	remaining: 1m 53s
# 236:	learn: 0.4151782	total: 35.2s	remaining: 1m 53s
# 237:	learn: 0.4151430	total: 35.3s	remaining: 1m 53s
# 238:	learn: 0.4150481	total: 35.4s	remaining: 1m 52s
# 239:	learn: 0.4149983	total: 35.6s	remaining: 1m 52s
# 240:	learn: 0.4149280	total: 35.7s	remaining: 1m 52s
# 241:	learn: 0.4148597	total: 35.9s	remaining: 1m 52s
# 242:	learn: 0.4148270	total: 36s	remaining: 1m 52s
# 243:	learn: 0.4147144	total: 36.2s	remaining: 1m 52s
# 244:	learn: 0.4146766	total: 36.3s	remaining: 1m 51s
# 245:	learn: 0.4146194	total: 36.4s	remaining: 1m 51s
# 246:	learn: 0.4145124	total: 36.6s	remaining: 1m 51s
# 247:	learn: 0.4144425	total: 36.7s	remaining: 1m 51s
# 248:	learn: 0.4143956	total: 36.9s	remaining: 1m 51s
# 249:	learn: 0.4143314	total: 37s	remaining: 1m 51s
# 250:	learn: 0.4142788	total: 37.1s	remaining: 1m 50s
# 251:	learn: 0.4142647	total: 37.3s	remaining: 1m 50s
# 252:	learn: 0.4142191	total: 37.4s	remaining: 1m 50s
# 253:	learn: 0.4141697	total: 37.5s	remaining: 1m 50s
# 254:	learn: 0.4140853	total: 37.7s	remaining: 1m 50s
# 255:	learn: 0.4140545	total: 37.8s	remaining: 1m 49s
# 256:	learn: 0.4140016	total: 37.9s	remaining: 1m 49s
# 257:	learn: 0.4139778	total: 38.1s	remaining: 1m 49s
# 258:	learn: 0.4139429	total: 38.2s	remaining: 1m 49s
# 259:	learn: 0.4138965	total: 38.4s	remaining: 1m 49s
# 260:	learn: 0.4138527	total: 38.6s	remaining: 1m 49s
# 261:	learn: 0.4138198	total: 38.7s	remaining: 1m 48s
# 262:	learn: 0.4137857	total: 38.8s	remaining: 1m 48s
# 263:	learn: 0.4137294	total: 39s	remaining: 1m 48s
# 264:	learn: 0.4136921	total: 39.1s	remaining: 1m 48s
# 265:	learn: 0.4136735	total: 39.3s	remaining: 1m 48s
# 266:	learn: 0.4135906	total: 39.4s	remaining: 1m 48s
# 267:	learn: 0.4134838	total: 39.6s	remaining: 1m 48s
# 268:	learn: 0.4134165	total: 39.7s	remaining: 1m 47s
# 269:	learn: 0.4133848	total: 39.8s	remaining: 1m 47s
# 270:	learn: 0.4133371	total: 40s	remaining: 1m 47s
# 271:	learn: 0.4132698	total: 40.1s	remaining: 1m 47s
# 272:	learn: 0.4131871	total: 40.3s	remaining: 1m 47s
# 273:	learn: 0.4130750	total: 40.4s	remaining: 1m 47s
# 274:	learn: 0.4129649	total: 40.6s	remaining: 1m 46s
# 275:	learn: 0.4128819	total: 40.7s	remaining: 1m 46s
# 276:	learn: 0.4127966	total: 40.9s	remaining: 1m 46s
# 277:	learn: 0.4127467	total: 41s	remaining: 1m 46s
# 278:	learn: 0.4126700	total: 41.1s	remaining: 1m 46s
# 279:	learn: 0.4126469	total: 41.3s	remaining: 1m 46s
# 280:	learn: 0.4126026	total: 41.4s	remaining: 1m 45s
# 281:	learn: 0.4125315	total: 41.5s	remaining: 1m 45s
# 282:	learn: 0.4124756	total: 41.7s	remaining: 1m 45s
# 283:	learn: 0.4124262	total: 41.8s	remaining: 1m 45s
# 284:	learn: 0.4123952	total: 41.9s	remaining: 1m 45s
# 285:	learn: 0.4123668	total: 42.1s	remaining: 1m 45s
# 286:	learn: 0.4123030	total: 42.2s	remaining: 1m 44s
# 287:	learn: 0.4122069	total: 42.3s	remaining: 1m 44s
# 288:	learn: 0.4121318	total: 42.5s	remaining: 1m 44s
# 289:	learn: 0.4120369	total: 42.6s	remaining: 1m 44s
# 290:	learn: 0.4120040	total: 42.8s	remaining: 1m 44s
# 291:	learn: 0.4119083	total: 42.9s	remaining: 1m 44s
# 292:	learn: 0.4118450	total: 43s	remaining: 1m 43s
# 293:	learn: 0.4117570	total: 43.2s	remaining: 1m 43s
# 294:	learn: 0.4117102	total: 43.3s	remaining: 1m 43s
# 295:	learn: 0.4116660	total: 43.5s	remaining: 1m 43s
# 296:	learn: 0.4116595	total: 43.6s	remaining: 1m 43s
# 297:	learn: 0.4116085	total: 43.8s	remaining: 1m 43s
# 298:	learn: 0.4115596	total: 43.9s	remaining: 1m 42s
# 299:	learn: 0.4114855	total: 44s	remaining: 1m 42s
# 300:	learn: 0.4114277	total: 44.2s	remaining: 1m 42s
# 301:	learn: 0.4113798	total: 44.4s	remaining: 1m 42s
# 302:	learn: 0.4113547	total: 44.5s	remaining: 1m 42s
# 303:	learn: 0.4113057	total: 44.6s	remaining: 1m 42s
# 304:	learn: 0.4112157	total: 44.7s	remaining: 1m 41s
# 305:	learn: 0.4112006	total: 44.8s	remaining: 1m 41s
# 306:	learn: 0.4111625	total: 45s	remaining: 1m 41s
# 307:	learn: 0.4111424	total: 45.2s	remaining: 1m 41s
# 308:	learn: 0.4111069	total: 45.3s	remaining: 1m 41s
# 309:	learn: 0.4109679	total: 45.4s	remaining: 1m 41s
# 310:	learn: 0.4109077	total: 45.6s	remaining: 1m 41s
# 311:	learn: 0.4108752	total: 45.8s	remaining: 1m 40s
# 312:	learn: 0.4108021	total: 45.9s	remaining: 1m 40s
# 313:	learn: 0.4107201	total: 46.1s	remaining: 1m 40s
# 314:	learn: 0.4106860	total: 46.2s	remaining: 1m 40s
# 315:	learn: 0.4106032	total: 46.3s	remaining: 1m 40s
# 316:	learn: 0.4105520	total: 46.5s	remaining: 1m 40s
# 317:	learn: 0.4104685	total: 46.6s	remaining: 1m 39s
# 318:	learn: 0.4104365	total: 46.8s	remaining: 1m 39s
# 319:	learn: 0.4104167	total: 47s	remaining: 1m 39s
# 320:	learn: 0.4103782	total: 47.1s	remaining: 1m 39s
# 321:	learn: 0.4103331	total: 47.3s	remaining: 1m 39s
# 322:	learn: 0.4103017	total: 47.4s	remaining: 1m 39s
# 323:	learn: 0.4102377	total: 47.5s	remaining: 1m 39s
# 324:	learn: 0.4101437	total: 47.7s	remaining: 1m 38s
# 325:	learn: 0.4101062	total: 47.8s	remaining: 1m 38s
# 326:	learn: 0.4100818	total: 47.9s	remaining: 1m 38s
# 327:	learn: 0.4100535	total: 48.1s	remaining: 1m 38s
# 328:	learn: 0.4099481	total: 48.2s	remaining: 1m 38s
# 329:	learn: 0.4099270	total: 48.4s	remaining: 1m 38s
# 330:	learn: 0.4098688	total: 48.5s	remaining: 1m 38s
# 331:	learn: 0.4098012	total: 48.7s	remaining: 1m 37s
# 332:	learn: 0.4097541	total: 48.8s	remaining: 1m 37s
# 333:	learn: 0.4096819	total: 48.9s	remaining: 1m 37s
# 334:	learn: 0.4096634	total: 49.1s	remaining: 1m 37s
# 335:	learn: 0.4096271	total: 49.2s	remaining: 1m 37s
# 336:	learn: 0.4095857	total: 49.3s	remaining: 1m 36s
# 337:	learn: 0.4095225	total: 49.4s	remaining: 1m 36s
# 338:	learn: 0.4094658	total: 49.6s	remaining: 1m 36s
# 339:	learn: 0.4094347	total: 49.7s	remaining: 1m 36s
# 340:	learn: 0.4093315	total: 49.8s	remaining: 1m 36s
# 341:	learn: 0.4093053	total: 49.9s	remaining: 1m 36s
# 342:	learn: 0.4092689	total: 50.1s	remaining: 1m 35s
# 343:	learn: 0.4092326	total: 50.2s	remaining: 1m 35s
# 344:	learn: 0.4091592	total: 50.4s	remaining: 1m 35s
# 345:	learn: 0.4091353	total: 50.5s	remaining: 1m 35s
# 346:	learn: 0.4091070	total: 50.6s	remaining: 1m 35s
# 347:	learn: 0.4090631	total: 50.8s	remaining: 1m 35s
# 348:	learn: 0.4090134	total: 50.9s	remaining: 1m 34s
# 349:	learn: 0.4089735	total: 51s	remaining: 1m 34s
# 350:	learn: 0.4089479	total: 51.2s	remaining: 1m 34s
# 351:	learn: 0.4088732	total: 51.3s	remaining: 1m 34s
# 352:	learn: 0.4088343	total: 51.5s	remaining: 1m 34s
# 353:	learn: 0.4087805	total: 51.6s	remaining: 1m 34s
# 354:	learn: 0.4087681	total: 51.7s	remaining: 1m 34s
# 355:	learn: 0.4087501	total: 51.9s	remaining: 1m 33s
# 356:	learn: 0.4087209	total: 52s	remaining: 1m 33s
# 357:	learn: 0.4086855	total: 52.2s	remaining: 1m 33s
# 358:	learn: 0.4086442	total: 52.3s	remaining: 1m 33s
# 359:	learn: 0.4085434	total: 52.5s	remaining: 1m 33s
# 360:	learn: 0.4085119	total: 52.6s	remaining: 1m 33s
# 361:	learn: 0.4084964	total: 52.7s	remaining: 1m 32s
# 362:	learn: 0.4084592	total: 52.8s	remaining: 1m 32s
# 363:	learn: 0.4084458	total: 53s	remaining: 1m 32s
# 364:	learn: 0.4084189	total: 53.1s	remaining: 1m 32s
# 365:	learn: 0.4083856	total: 53.3s	remaining: 1m 32s
# 366:	learn: 0.4083342	total: 53.4s	remaining: 1m 32s
# 367:	learn: 0.4083132	total: 53.5s	remaining: 1m 31s
# 368:	learn: 0.4082712	total: 53.6s	remaining: 1m 31s
# 369:	learn: 0.4082309	total: 53.8s	remaining: 1m 31s
# 370:	learn: 0.4081758	total: 53.9s	remaining: 1m 31s
# 371:	learn: 0.4081426	total: 54.1s	remaining: 1m 31s
# 372:	learn: 0.4081216	total: 54.2s	remaining: 1m 31s
# 373:	learn: 0.4080835	total: 54.4s	remaining: 1m 30s
# 374:	learn: 0.4080456	total: 54.5s	remaining: 1m 30s
# 375:	learn: 0.4079897	total: 54.6s	remaining: 1m 30s
# 376:	learn: 0.4079688	total: 54.8s	remaining: 1m 30s
# 377:	learn: 0.4079147	total: 54.9s	remaining: 1m 30s
# 378:	learn: 0.4078676	total: 55.1s	remaining: 1m 30s
# 379:	learn: 0.4078277	total: 55.2s	remaining: 1m 30s
# 380:	learn: 0.4077626	total: 55.4s	remaining: 1m 30s
# 381:	learn: 0.4077148	total: 55.5s	remaining: 1m 29s
# 382:	learn: 0.4076783	total: 55.7s	remaining: 1m 29s
# 383:	learn: 0.4076479	total: 55.8s	remaining: 1m 29s
# 384:	learn: 0.4076276	total: 55.9s	remaining: 1m 29s
# 385:	learn: 0.4076008	total: 56.1s	remaining: 1m 29s
# 386:	learn: 0.4075517	total: 56.2s	remaining: 1m 28s
# 387:	learn: 0.4075266	total: 56.3s	remaining: 1m 28s
# 388:	learn: 0.4075133	total: 56.5s	remaining: 1m 28s
# 389:	learn: 0.4075044	total: 56.6s	remaining: 1m 28s
# 390:	learn: 0.4074768	total: 56.7s	remaining: 1m 28s
# 391:	learn: 0.4074566	total: 56.9s	remaining: 1m 28s
# 392:	learn: 0.4073861	total: 57s	remaining: 1m 28s
# 393:	learn: 0.4073518	total: 57.2s	remaining: 1m 27s
# 394:	learn: 0.4073422	total: 57.3s	remaining: 1m 27s
# 395:	learn: 0.4072882	total: 57.5s	remaining: 1m 27s
# 396:	learn: 0.4072786	total: 57.6s	remaining: 1m 27s
# 397:	learn: 0.4072447	total: 57.8s	remaining: 1m 27s
# 398:	learn: 0.4072307	total: 57.9s	remaining: 1m 27s
# 399:	learn: 0.4072140	total: 58s	remaining: 1m 26s
# 400:	learn: 0.4071667	total: 58.1s	remaining: 1m 26s
# 401:	learn: 0.4071323	total: 58.3s	remaining: 1m 26s
# 402:	learn: 0.4071000	total: 58.4s	remaining: 1m 26s
# 403:	learn: 0.4070640	total: 58.5s	remaining: 1m 26s
# 404:	learn: 0.4070318	total: 58.6s	remaining: 1m 26s
# 405:	learn: 0.4070050	total: 58.8s	remaining: 1m 25s
# 406:	learn: 0.4069737	total: 58.9s	remaining: 1m 25s
# 407:	learn: 0.4069217	total: 59.1s	remaining: 1m 25s
# 408:	learn: 0.4068764	total: 59.2s	remaining: 1m 25s
# 409:	learn: 0.4068094	total: 59.4s	remaining: 1m 25s
# 410:	learn: 0.4067905	total: 59.5s	remaining: 1m 25s
# 411:	learn: 0.4067612	total: 59.7s	remaining: 1m 25s
# 412:	learn: 0.4066892	total: 59.8s	remaining: 1m 24s
# 413:	learn: 0.4066807	total: 59.9s	remaining: 1m 24s
# 414:	learn: 0.4066350	total: 1m	remaining: 1m 24s
# 415:	learn: 0.4066046	total: 1m	remaining: 1m 24s
# 416:	learn: 0.4065838	total: 1m	remaining: 1m 24s
# 417:	learn: 0.4065454	total: 1m	remaining: 1m 24s
# 418:	learn: 0.4065242	total: 1m	remaining: 1m 24s
# 419:	learn: 0.4064728	total: 1m	remaining: 1m 23s
# 420:	learn: 0.4064248	total: 1m	remaining: 1m 23s
# 421:	learn: 0.4063854	total: 1m 1s	remaining: 1m 23s
# 422:	learn: 0.4063359	total: 1m 1s	remaining: 1m 23s
# 423:	learn: 0.4062955	total: 1m 1s	remaining: 1m 23s
# 424:	learn: 0.4062520	total: 1m 1s	remaining: 1m 23s
# 425:	learn: 0.4061403	total: 1m 1s	remaining: 1m 23s
# 426:	learn: 0.4061186	total: 1m 1s	remaining: 1m 22s
# 427:	learn: 0.4060861	total: 1m 1s	remaining: 1m 22s
# 428:	learn: 0.4060478	total: 1m 2s	remaining: 1m 22s
# 429:	learn: 0.4060126	total: 1m 2s	remaining: 1m 22s
# 430:	learn: 0.4059603	total: 1m 2s	remaining: 1m 22s
# 431:	learn: 0.4059256	total: 1m 2s	remaining: 1m 22s
# 432:	learn: 0.4058911	total: 1m 2s	remaining: 1m 22s
# 433:	learn: 0.4058277	total: 1m 2s	remaining: 1m 21s
# 434:	learn: 0.4057761	total: 1m 2s	remaining: 1m 21s
# 435:	learn: 0.4057330	total: 1m 3s	remaining: 1m 21s
# 436:	learn: 0.4056868	total: 1m 3s	remaining: 1m 21s
# 437:	learn: 0.4056382	total: 1m 3s	remaining: 1m 21s
# 438:	learn: 0.4056004	total: 1m 3s	remaining: 1m 21s
# 439:	learn: 0.4055779	total: 1m 3s	remaining: 1m 21s
# 440:	learn: 0.4055299	total: 1m 3s	remaining: 1m 20s
# 441:	learn: 0.4055017	total: 1m 3s	remaining: 1m 20s
# 442:	learn: 0.4054646	total: 1m 4s	remaining: 1m 20s
# 443:	learn: 0.4054358	total: 1m 4s	remaining: 1m 20s
# 444:	learn: 0.4054074	total: 1m 4s	remaining: 1m 20s
# 445:	learn: 0.4053909	total: 1m 4s	remaining: 1m 20s
# 446:	learn: 0.4053788	total: 1m 4s	remaining: 1m 19s
# 447:	learn: 0.4053159	total: 1m 4s	remaining: 1m 19s
# 448:	learn: 0.4052820	total: 1m 4s	remaining: 1m 19s
# 449:	learn: 0.4052646	total: 1m 5s	remaining: 1m 19s
# 450:	learn: 0.4052322	total: 1m 5s	remaining: 1m 19s
# 451:	learn: 0.4051823	total: 1m 5s	remaining: 1m 19s
# 452:	learn: 0.4051263	total: 1m 5s	remaining: 1m 19s
# 453:	learn: 0.4050749	total: 1m 5s	remaining: 1m 18s
# 454:	learn: 0.4050147	total: 1m 5s	remaining: 1m 18s
# 455:	learn: 0.4049708	total: 1m 5s	remaining: 1m 18s
# 456:	learn: 0.4049422	total: 1m 6s	remaining: 1m 18s
# 457:	learn: 0.4048994	total: 1m 6s	remaining: 1m 18s
# 458:	learn: 0.4048843	total: 1m 6s	remaining: 1m 18s
# 459:	learn: 0.4048271	total: 1m 6s	remaining: 1m 17s
# 460:	learn: 0.4047990	total: 1m 6s	remaining: 1m 17s
# 461:	learn: 0.4047256	total: 1m 6s	remaining: 1m 17s
# 462:	learn: 0.4046769	total: 1m 6s	remaining: 1m 17s
# 463:	learn: 0.4046612	total: 1m 7s	remaining: 1m 17s
# 464:	learn: 0.4046313	total: 1m 7s	remaining: 1m 17s
# 465:	learn: 0.4046071	total: 1m 7s	remaining: 1m 17s
# 466:	learn: 0.4045328	total: 1m 7s	remaining: 1m 16s
# 467:	learn: 0.4045238	total: 1m 7s	remaining: 1m 16s
# 468:	learn: 0.4044726	total: 1m 7s	remaining: 1m 16s
# 469:	learn: 0.4044273	total: 1m 7s	remaining: 1m 16s
# 470:	learn: 0.4043959	total: 1m 8s	remaining: 1m 16s
# 471:	learn: 0.4043508	total: 1m 8s	remaining: 1m 16s
# 472:	learn: 0.4043211	total: 1m 8s	remaining: 1m 16s
# 473:	learn: 0.4042880	total: 1m 8s	remaining: 1m 15s
# 474:	learn: 0.4042695	total: 1m 8s	remaining: 1m 15s
# 475:	learn: 0.4042478	total: 1m 8s	remaining: 1m 15s
# 476:	learn: 0.4041846	total: 1m 8s	remaining: 1m 15s
# 477:	learn: 0.4041389	total: 1m 8s	remaining: 1m 15s
# 478:	learn: 0.4040893	total: 1m 9s	remaining: 1m 15s
# 479:	learn: 0.4040511	total: 1m 9s	remaining: 1m 15s
# 480:	learn: 0.4040254	total: 1m 9s	remaining: 1m 14s
# 481:	learn: 0.4040038	total: 1m 9s	remaining: 1m 14s
# 482:	learn: 0.4039552	total: 1m 9s	remaining: 1m 14s
# 483:	learn: 0.4039210	total: 1m 9s	remaining: 1m 14s
# 484:	learn: 0.4038990	total: 1m 9s	remaining: 1m 14s
# 485:	learn: 0.4038581	total: 1m 10s	remaining: 1m 14s
# 486:	learn: 0.4038156	total: 1m 10s	remaining: 1m 13s
# 487:	learn: 0.4038007	total: 1m 10s	remaining: 1m 13s
# 488:	learn: 0.4037284	total: 1m 10s	remaining: 1m 13s
# 489:	learn: 0.4036717	total: 1m 10s	remaining: 1m 13s
# 490:	learn: 0.4036522	total: 1m 10s	remaining: 1m 13s
# 491:	learn: 0.4036243	total: 1m 10s	remaining: 1m 13s
# 492:	learn: 0.4035974	total: 1m 11s	remaining: 1m 13s
# 493:	learn: 0.4035656	total: 1m 11s	remaining: 1m 12s
# 494:	learn: 0.4035342	total: 1m 11s	remaining: 1m 12s
# 495:	learn: 0.4035136	total: 1m 11s	remaining: 1m 12s
# 496:	learn: 0.4034750	total: 1m 11s	remaining: 1m 12s
# 497:	learn: 0.4034600	total: 1m 11s	remaining: 1m 12s
# 498:	learn: 0.4033813	total: 1m 11s	remaining: 1m 12s
# 499:	learn: 0.4033486	total: 1m 11s	remaining: 1m 11s
# 500:	learn: 0.4033241	total: 1m 12s	remaining: 1m 11s
# 501:	learn: 0.4032565	total: 1m 12s	remaining: 1m 11s
# 502:	learn: 0.4032369	total: 1m 12s	remaining: 1m 11s
# 503:	learn: 0.4031964	total: 1m 12s	remaining: 1m 11s
# 504:	learn: 0.4031608	total: 1m 12s	remaining: 1m 11s
# 505:	learn: 0.4031346	total: 1m 12s	remaining: 1m 11s
# 506:	learn: 0.4031211	total: 1m 12s	remaining: 1m 10s
# 507:	learn: 0.4030894	total: 1m 13s	remaining: 1m 10s
# 508:	learn: 0.4030567	total: 1m 13s	remaining: 1m 10s
# 509:	learn: 0.4030246	total: 1m 13s	remaining: 1m 10s
# 510:	learn: 0.4029903	total: 1m 13s	remaining: 1m 10s
# 511:	learn: 0.4029775	total: 1m 13s	remaining: 1m 10s
# 512:	learn: 0.4029370	total: 1m 13s	remaining: 1m 10s
# 513:	learn: 0.4029342	total: 1m 13s	remaining: 1m 9s
# 514:	learn: 0.4028993	total: 1m 13s	remaining: 1m 9s
# 515:	learn: 0.4028862	total: 1m 14s	remaining: 1m 9s
# 516:	learn: 0.4028268	total: 1m 14s	remaining: 1m 9s
# 517:	learn: 0.4027914	total: 1m 14s	remaining: 1m 9s
# 518:	learn: 0.4027392	total: 1m 14s	remaining: 1m 9s
# 519:	learn: 0.4026922	total: 1m 14s	remaining: 1m 8s
# 520:	learn: 0.4026498	total: 1m 14s	remaining: 1m 8s
# 521:	learn: 0.4025939	total: 1m 14s	remaining: 1m 8s
# 522:	learn: 0.4025820	total: 1m 15s	remaining: 1m 8s
# 523:	learn: 0.4025217	total: 1m 15s	remaining: 1m 8s
# 524:	learn: 0.4024794	total: 1m 15s	remaining: 1m 8s
# 525:	learn: 0.4024701	total: 1m 15s	remaining: 1m 7s
# 526:	learn: 0.4024543	total: 1m 15s	remaining: 1m 7s
# 527:	learn: 0.4024223	total: 1m 15s	remaining: 1m 7s
# 528:	learn: 0.4023764	total: 1m 15s	remaining: 1m 7s
# 529:	learn: 0.4023605	total: 1m 15s	remaining: 1m 7s
# 530:	learn: 0.4023078	total: 1m 16s	remaining: 1m 7s
# 531:	learn: 0.4022228	total: 1m 16s	remaining: 1m 7s
# 532:	learn: 0.4022012	total: 1m 16s	remaining: 1m 6s
# 533:	learn: 0.4021715	total: 1m 16s	remaining: 1m 6s
# 534:	learn: 0.4021508	total: 1m 16s	remaining: 1m 6s
# 535:	learn: 0.4021024	total: 1m 16s	remaining: 1m 6s
# 536:	learn: 0.4020473	total: 1m 16s	remaining: 1m 6s
# 537:	learn: 0.4020090	total: 1m 17s	remaining: 1m 6s
# 538:	learn: 0.4019773	total: 1m 17s	remaining: 1m 6s
# 539:	learn: 0.4019376	total: 1m 17s	remaining: 1m 5s
# 540:	learn: 0.4019029	total: 1m 17s	remaining: 1m 5s
# 541:	learn: 0.4018734	total: 1m 17s	remaining: 1m 5s
# 542:	learn: 0.4018399	total: 1m 17s	remaining: 1m 5s
# 543:	learn: 0.4018089	total: 1m 17s	remaining: 1m 5s
# 544:	learn: 0.4017667	total: 1m 18s	remaining: 1m 5s
# 545:	learn: 0.4017432	total: 1m 18s	remaining: 1m 4s
# 546:	learn: 0.4017047	total: 1m 18s	remaining: 1m 4s
# 547:	learn: 0.4016816	total: 1m 18s	remaining: 1m 4s
# 548:	learn: 0.4016474	total: 1m 18s	remaining: 1m 4s
# 549:	learn: 0.4016216	total: 1m 18s	remaining: 1m 4s
# 550:	learn: 0.4015690	total: 1m 18s	remaining: 1m 4s
# 551:	learn: 0.4015280	total: 1m 18s	remaining: 1m 4s
# 552:	learn: 0.4015096	total: 1m 19s	remaining: 1m 3s
# 553:	learn: 0.4014574	total: 1m 19s	remaining: 1m 3s
# 554:	learn: 0.4014472	total: 1m 19s	remaining: 1m 3s
# 555:	learn: 0.4014102	total: 1m 19s	remaining: 1m 3s
# 556:	learn: 0.4013953	total: 1m 19s	remaining: 1m 3s
# 557:	learn: 0.4013641	total: 1m 19s	remaining: 1m 3s
# 558:	learn: 0.4013310	total: 1m 19s	remaining: 1m 3s
# 559:	learn: 0.4013134	total: 1m 20s	remaining: 1m 2s
# 560:	learn: 0.4012458	total: 1m 20s	remaining: 1m 2s
# 561:	learn: 0.4012133	total: 1m 20s	remaining: 1m 2s
# 562:	learn: 0.4011601	total: 1m 20s	remaining: 1m 2s
# 563:	learn: 0.4011025	total: 1m 20s	remaining: 1m 2s
# 564:	learn: 0.4010760	total: 1m 20s	remaining: 1m 2s
# 565:	learn: 0.4010383	total: 1m 20s	remaining: 1m 2s
# 566:	learn: 0.4009932	total: 1m 21s	remaining: 1m 1s
# 567:	learn: 0.4009741	total: 1m 21s	remaining: 1m 1s
# 568:	learn: 0.4009463	total: 1m 21s	remaining: 1m 1s
# 569:	learn: 0.4009180	total: 1m 21s	remaining: 1m 1s
# 570:	learn: 0.4009044	total: 1m 21s	remaining: 1m 1s
# 571:	learn: 0.4008637	total: 1m 21s	remaining: 1m 1s
# 572:	learn: 0.4008216	total: 1m 21s	remaining: 1m 1s
# 573:	learn: 0.4007596	total: 1m 22s	remaining: 1m
# 574:	learn: 0.4007042	total: 1m 22s	remaining: 1m
# 575:	learn: 0.4006722	total: 1m 22s	remaining: 1m
# 576:	learn: 0.4006593	total: 1m 22s	remaining: 1m
# 577:	learn: 0.4006260	total: 1m 22s	remaining: 1m
# 578:	learn: 0.4005870	total: 1m 22s	remaining: 1m
# 579:	learn: 0.4005720	total: 1m 22s	remaining: 1m
# 580:	learn: 0.4005315	total: 1m 23s	remaining: 59.9s
# 581:	learn: 0.4005098	total: 1m 23s	remaining: 59.8s
# 582:	learn: 0.4004603	total: 1m 23s	remaining: 59.6s
# 583:	learn: 0.4004324	total: 1m 23s	remaining: 59.5s
# 584:	learn: 0.4003868	total: 1m 23s	remaining: 59.3s
# 585:	learn: 0.4003540	total: 1m 23s	remaining: 59.2s
# 586:	learn: 0.4003234	total: 1m 23s	remaining: 59.1s
# 587:	learn: 0.4003156	total: 1m 24s	remaining: 58.9s
# 588:	learn: 0.4002743	total: 1m 24s	remaining: 58.8s
# 589:	learn: 0.4002240	total: 1m 24s	remaining: 58.6s
# 590:	learn: 0.4002109	total: 1m 24s	remaining: 58.5s
# 591:	learn: 0.4001711	total: 1m 24s	remaining: 58.4s
# 592:	learn: 0.4001336	total: 1m 24s	remaining: 58.2s
# 593:	learn: 0.4000867	total: 1m 24s	remaining: 58.1s
# 594:	learn: 0.4000240	total: 1m 25s	remaining: 57.9s
# 595:	learn: 0.3999972	total: 1m 25s	remaining: 57.8s
# 596:	learn: 0.3999711	total: 1m 25s	remaining: 57.7s
# 597:	learn: 0.3999240	total: 1m 25s	remaining: 57.6s
# 598:	learn: 0.3999034	total: 1m 25s	remaining: 57.4s
# 599:	learn: 0.3998481	total: 1m 25s	remaining: 57.3s
# 600:	learn: 0.3998206	total: 1m 26s	remaining: 57.2s
# 601:	learn: 0.3998074	total: 1m 26s	remaining: 57s
# 602:	learn: 0.3997528	total: 1m 26s	remaining: 56.9s
# 603:	learn: 0.3997227	total: 1m 26s	remaining: 56.7s
# 604:	learn: 0.3997012	total: 1m 26s	remaining: 56.6s
# 605:	learn: 0.3996629	total: 1m 26s	remaining: 56.5s
# 606:	learn: 0.3996424	total: 1m 26s	remaining: 56.3s
# 607:	learn: 0.3996100	total: 1m 27s	remaining: 56.1s
# 608:	learn: 0.3995861	total: 1m 27s	remaining: 56s
# 609:	learn: 0.3995589	total: 1m 27s	remaining: 55.8s
# 610:	learn: 0.3995366	total: 1m 27s	remaining: 55.7s
# 611:	learn: 0.3995016	total: 1m 27s	remaining: 55.5s
# 612:	learn: 0.3994763	total: 1m 27s	remaining: 55.4s
# 613:	learn: 0.3994453	total: 1m 27s	remaining: 55.2s
# 614:	learn: 0.3994289	total: 1m 28s	remaining: 55.1s
# 615:	learn: 0.3994037	total: 1m 28s	remaining: 54.9s
# 616:	learn: 0.3993829	total: 1m 28s	remaining: 54.8s
# 617:	learn: 0.3993632	total: 1m 28s	remaining: 54.6s
# 618:	learn: 0.3993485	total: 1m 28s	remaining: 54.5s
# 619:	learn: 0.3993336	total: 1m 28s	remaining: 54.4s
# 620:	learn: 0.3993029	total: 1m 28s	remaining: 54.2s
# 621:	learn: 0.3992581	total: 1m 29s	remaining: 54.1s
# 622:	learn: 0.3992053	total: 1m 29s	remaining: 53.9s
# 623:	learn: 0.3991323	total: 1m 29s	remaining: 53.8s
# 624:	learn: 0.3991046	total: 1m 29s	remaining: 53.7s
# 625:	learn: 0.3990644	total: 1m 29s	remaining: 53.6s
# 626:	learn: 0.3990178	total: 1m 29s	remaining: 53.4s
# 627:	learn: 0.3988816	total: 1m 29s	remaining: 53.3s
# 628:	learn: 0.3988651	total: 1m 30s	remaining: 53.1s
# 629:	learn: 0.3988405	total: 1m 30s	remaining: 53s
# 630:	learn: 0.3988132	total: 1m 30s	remaining: 52.9s
# 631:	learn: 0.3987600	total: 1m 30s	remaining: 52.7s
# 632:	learn: 0.3987274	total: 1m 30s	remaining: 52.6s
# 633:	learn: 0.3986625	total: 1m 30s	remaining: 52.4s
# 634:	learn: 0.3986384	total: 1m 30s	remaining: 52.3s
# 635:	learn: 0.3986080	total: 1m 31s	remaining: 52.1s
# 636:	learn: 0.3985829	total: 1m 31s	remaining: 52s
# 637:	learn: 0.3984948	total: 1m 31s	remaining: 51.8s
# 638:	learn: 0.3984468	total: 1m 31s	remaining: 51.7s
# 639:	learn: 0.3984161	total: 1m 31s	remaining: 51.6s
# 640:	learn: 0.3983743	total: 1m 31s	remaining: 51.4s
# 641:	learn: 0.3983569	total: 1m 31s	remaining: 51.3s
# 642:	learn: 0.3983295	total: 1m 32s	remaining: 51.1s
# 643:	learn: 0.3983038	total: 1m 32s	remaining: 51s
# 644:	learn: 0.3982643	total: 1m 32s	remaining: 50.8s
# 645:	learn: 0.3982209	total: 1m 32s	remaining: 50.7s
# 646:	learn: 0.3981862	total: 1m 32s	remaining: 50.6s
# 647:	learn: 0.3981564	total: 1m 32s	remaining: 50.4s
# 648:	learn: 0.3981477	total: 1m 32s	remaining: 50.3s
# 649:	learn: 0.3981174	total: 1m 33s	remaining: 50.1s
# 650:	learn: 0.3980869	total: 1m 33s	remaining: 50s
# 651:	learn: 0.3980722	total: 1m 33s	remaining: 49.8s
# 652:	learn: 0.3980462	total: 1m 33s	remaining: 49.7s
# 653:	learn: 0.3980048	total: 1m 33s	remaining: 49.5s
# 654:	learn: 0.3979804	total: 1m 33s	remaining: 49.4s
# 655:	learn: 0.3979332	total: 1m 33s	remaining: 49.3s
# 656:	learn: 0.3979093	total: 1m 34s	remaining: 49.1s
# 657:	learn: 0.3978876	total: 1m 34s	remaining: 49s
# 658:	learn: 0.3978589	total: 1m 34s	remaining: 48.8s
# 659:	learn: 0.3978395	total: 1m 34s	remaining: 48.7s
# 660:	learn: 0.3977822	total: 1m 34s	remaining: 48.5s
# 661:	learn: 0.3977679	total: 1m 34s	remaining: 48.4s
# 662:	learn: 0.3977350	total: 1m 34s	remaining: 48.2s
# 663:	learn: 0.3976985	total: 1m 35s	remaining: 48.1s
# 664:	learn: 0.3976602	total: 1m 35s	remaining: 47.9s
# 665:	learn: 0.3976528	total: 1m 35s	remaining: 47.8s
# 666:	learn: 0.3976367	total: 1m 35s	remaining: 47.7s
# 667:	learn: 0.3976059	total: 1m 35s	remaining: 47.5s
# 668:	learn: 0.3975860	total: 1m 35s	remaining: 47.4s
# 669:	learn: 0.3975615	total: 1m 35s	remaining: 47.3s
# 670:	learn: 0.3975398	total: 1m 36s	remaining: 47.1s
# 671:	learn: 0.3974942	total: 1m 36s	remaining: 47s
# 672:	learn: 0.3974811	total: 1m 36s	remaining: 46.8s
# 673:	learn: 0.3974547	total: 1m 36s	remaining: 46.7s
# 674:	learn: 0.3974331	total: 1m 36s	remaining: 46.5s
# 675:	learn: 0.3973831	total: 1m 36s	remaining: 46.4s
# 676:	learn: 0.3973616	total: 1m 36s	remaining: 46.2s
# 677:	learn: 0.3973192	total: 1m 37s	remaining: 46.1s
# 678:	learn: 0.3973003	total: 1m 37s	remaining: 46s
# 679:	learn: 0.3972941	total: 1m 37s	remaining: 45.8s
# 680:	learn: 0.3972700	total: 1m 37s	remaining: 45.6s
# 681:	learn: 0.3972474	total: 1m 37s	remaining: 45.5s
# 682:	learn: 0.3971886	total: 1m 37s	remaining: 45.4s
# 683:	learn: 0.3971472	total: 1m 37s	remaining: 45.2s
# 684:	learn: 0.3970970	total: 1m 38s	remaining: 45.1s
# 685:	learn: 0.3970407	total: 1m 38s	remaining: 44.9s
# 686:	learn: 0.3970204	total: 1m 38s	remaining: 44.8s
# 687:	learn: 0.3969949	total: 1m 38s	remaining: 44.6s
# 688:	learn: 0.3969038	total: 1m 38s	remaining: 44.5s
# 689:	learn: 0.3968636	total: 1m 38s	remaining: 44.3s
# 690:	learn: 0.3968474	total: 1m 38s	remaining: 44.2s
# 691:	learn: 0.3968229	total: 1m 38s	remaining: 44s
# 692:	learn: 0.3967851	total: 1m 39s	remaining: 43.9s
# 693:	learn: 0.3967369	total: 1m 39s	remaining: 43.7s
# 694:	learn: 0.3967179	total: 1m 39s	remaining: 43.6s
# 695:	learn: 0.3966783	total: 1m 39s	remaining: 43.5s
# 696:	learn: 0.3966596	total: 1m 39s	remaining: 43.3s
# 697:	learn: 0.3966486	total: 1m 39s	remaining: 43.2s
# 698:	learn: 0.3966071	total: 1m 39s	remaining: 43s
# 699:	learn: 0.3965577	total: 1m 40s	remaining: 42.9s
# 700:	learn: 0.3965200	total: 1m 40s	remaining: 42.7s
# 701:	learn: 0.3965012	total: 1m 40s	remaining: 42.6s
# 702:	learn: 0.3964800	total: 1m 40s	remaining: 42.4s
# 703:	learn: 0.3964276	total: 1m 40s	remaining: 42.3s
# 704:	learn: 0.3964062	total: 1m 40s	remaining: 42.1s
# 705:	learn: 0.3963792	total: 1m 40s	remaining: 42s
# 706:	learn: 0.3963420	total: 1m 40s	remaining: 41.8s
# 707:	learn: 0.3963056	total: 1m 41s	remaining: 41.7s
# 708:	learn: 0.3962144	total: 1m 41s	remaining: 41.6s
# 709:	learn: 0.3961791	total: 1m 41s	remaining: 41.4s
# 710:	learn: 0.3961379	total: 1m 41s	remaining: 41.3s
# 711:	learn: 0.3961202	total: 1m 41s	remaining: 41.1s
# 712:	learn: 0.3960791	total: 1m 41s	remaining: 41s
# 713:	learn: 0.3960279	total: 1m 42s	remaining: 40.9s
# 714:	learn: 0.3959666	total: 1m 42s	remaining: 40.7s
# 715:	learn: 0.3959398	total: 1m 42s	remaining: 40.6s
# 716:	learn: 0.3959119	total: 1m 42s	remaining: 40.4s
# 717:	learn: 0.3958781	total: 1m 42s	remaining: 40.3s
# 718:	learn: 0.3958263	total: 1m 42s	remaining: 40.1s
# 719:	learn: 0.3957569	total: 1m 42s	remaining: 40s
# 720:	learn: 0.3957369	total: 1m 42s	remaining: 39.8s
# 721:	learn: 0.3956759	total: 1m 43s	remaining: 39.7s
# 722:	learn: 0.3956464	total: 1m 43s	remaining: 39.6s
# 723:	learn: 0.3956165	total: 1m 43s	remaining: 39.4s
# 724:	learn: 0.3955790	total: 1m 43s	remaining: 39.3s
# 725:	learn: 0.3955285	total: 1m 43s	remaining: 39.1s
# 726:	learn: 0.3955078	total: 1m 43s	remaining: 39s
# 727:	learn: 0.3954544	total: 1m 44s	remaining: 38.9s
# 728:	learn: 0.3954334	total: 1m 44s	remaining: 38.7s
# 729:	learn: 0.3954107	total: 1m 44s	remaining: 38.6s
# 730:	learn: 0.3953737	total: 1m 44s	remaining: 38.4s
# 731:	learn: 0.3953137	total: 1m 44s	remaining: 38.3s
# 732:	learn: 0.3952703	total: 1m 44s	remaining: 38.1s
# 733:	learn: 0.3952524	total: 1m 44s	remaining: 38s
# 734:	learn: 0.3952260	total: 1m 45s	remaining: 37.9s
# 735:	learn: 0.3951931	total: 1m 45s	remaining: 37.7s
# 736:	learn: 0.3951339	total: 1m 45s	remaining: 37.6s
# 737:	learn: 0.3951037	total: 1m 45s	remaining: 37.4s
# 738:	learn: 0.3950509	total: 1m 45s	remaining: 37.3s
# 739:	learn: 0.3950236	total: 1m 45s	remaining: 37.1s
# 740:	learn: 0.3949823	total: 1m 45s	remaining: 37s
# 741:	learn: 0.3949661	total: 1m 45s	remaining: 36.8s
# 742:	learn: 0.3949341	total: 1m 46s	remaining: 36.7s
# 743:	learn: 0.3948892	total: 1m 46s	remaining: 36.6s
# 744:	learn: 0.3948784	total: 1m 46s	remaining: 36.4s
# 745:	learn: 0.3948540	total: 1m 46s	remaining: 36.3s
# 746:	learn: 0.3948187	total: 1m 46s	remaining: 36.1s
# 747:	learn: 0.3947960	total: 1m 46s	remaining: 36s
# 748:	learn: 0.3947719	total: 1m 46s	remaining: 35.8s
# 749:	learn: 0.3947437	total: 1m 47s	remaining: 35.7s
# 750:	learn: 0.3947035	total: 1m 47s	remaining: 35.5s
# 751:	learn: 0.3946459	total: 1m 47s	remaining: 35.4s
# 752:	learn: 0.3946121	total: 1m 47s	remaining: 35.2s
# 753:	learn: 0.3945825	total: 1m 47s	remaining: 35.1s
# 754:	learn: 0.3945575	total: 1m 47s	remaining: 34.9s
# 755:	learn: 0.3945295	total: 1m 47s	remaining: 34.8s
# 756:	learn: 0.3944982	total: 1m 47s	remaining: 34.7s
# 757:	learn: 0.3944803	total: 1m 48s	remaining: 34.5s
# 758:	learn: 0.3944339	total: 1m 48s	remaining: 34.4s
# 759:	learn: 0.3944172	total: 1m 48s	remaining: 34.2s
# 760:	learn: 0.3943785	total: 1m 48s	remaining: 34.1s
# 761:	learn: 0.3943695	total: 1m 48s	remaining: 33.9s
# 762:	learn: 0.3943280	total: 1m 48s	remaining: 33.8s
# 763:	learn: 0.3942672	total: 1m 48s	remaining: 33.6s
# 764:	learn: 0.3942045	total: 1m 49s	remaining: 33.5s
# 765:	learn: 0.3941722	total: 1m 49s	remaining: 33.3s
# 766:	learn: 0.3941412	total: 1m 49s	remaining: 33.2s
# 767:	learn: 0.3941112	total: 1m 49s	remaining: 33.1s
# 768:	learn: 0.3940860	total: 1m 49s	remaining: 32.9s
# 769:	learn: 0.3940430	total: 1m 49s	remaining: 32.8s
# 770:	learn: 0.3940110	total: 1m 49s	remaining: 32.6s
# 771:	learn: 0.3939888	total: 1m 50s	remaining: 32.5s
# 772:	learn: 0.3939370	total: 1m 50s	remaining: 32.4s
# 773:	learn: 0.3938926	total: 1m 50s	remaining: 32.2s
# 774:	learn: 0.3938714	total: 1m 50s	remaining: 32.1s
# 775:	learn: 0.3938653	total: 1m 50s	remaining: 31.9s
# 776:	learn: 0.3938578	total: 1m 50s	remaining: 31.8s
# 777:	learn: 0.3938467	total: 1m 50s	remaining: 31.6s
# 778:	learn: 0.3938298	total: 1m 51s	remaining: 31.5s
# 779:	learn: 0.3938108	total: 1m 51s	remaining: 31.4s
# 780:	learn: 0.3937854	total: 1m 51s	remaining: 31.2s
# 781:	learn: 0.3937534	total: 1m 51s	remaining: 31.1s
# 782:	learn: 0.3937321	total: 1m 51s	remaining: 30.9s
# 783:	learn: 0.3936113	total: 1m 51s	remaining: 30.8s
# 784:	learn: 0.3935852	total: 1m 51s	remaining: 30.6s
# 785:	learn: 0.3935648	total: 1m 51s	remaining: 30.5s
# 786:	learn: 0.3935505	total: 1m 52s	remaining: 30.3s
# 787:	learn: 0.3935364	total: 1m 52s	remaining: 30.2s
# 788:	learn: 0.3935213	total: 1m 52s	remaining: 30.1s
# 789:	learn: 0.3934739	total: 1m 52s	remaining: 29.9s
# 790:	learn: 0.3934635	total: 1m 52s	remaining: 29.8s
# 791:	learn: 0.3934139	total: 1m 52s	remaining: 29.6s
# 792:	learn: 0.3933670	total: 1m 52s	remaining: 29.5s
# 793:	learn: 0.3933451	total: 1m 53s	remaining: 29.3s
# 794:	learn: 0.3933302	total: 1m 53s	remaining: 29.2s
# 795:	learn: 0.3933171	total: 1m 53s	remaining: 29.1s
# 796:	learn: 0.3932719	total: 1m 53s	remaining: 28.9s
# 797:	learn: 0.3932350	total: 1m 53s	remaining: 28.8s
# 798:	learn: 0.3931978	total: 1m 53s	remaining: 28.6s
# 799:	learn: 0.3931434	total: 1m 53s	remaining: 28.5s
# 800:	learn: 0.3930858	total: 1m 54s	remaining: 28.4s
# 801:	learn: 0.3930510	total: 1m 54s	remaining: 28.2s
# 802:	learn: 0.3930310	total: 1m 54s	remaining: 28.1s
# 803:	learn: 0.3929990	total: 1m 54s	remaining: 27.9s
# 804:	learn: 0.3929637	total: 1m 54s	remaining: 27.8s
# 805:	learn: 0.3929283	total: 1m 54s	remaining: 27.7s
# 806:	learn: 0.3929149	total: 1m 55s	remaining: 27.5s
# 807:	learn: 0.3928619	total: 1m 55s	remaining: 27.4s
# 808:	learn: 0.3928179	total: 1m 55s	remaining: 27.2s
# 809:	learn: 0.3927512	total: 1m 55s	remaining: 27.1s
# 810:	learn: 0.3927316	total: 1m 55s	remaining: 26.9s
# 811:	learn: 0.3926755	total: 1m 55s	remaining: 26.8s
# 812:	learn: 0.3926449	total: 1m 55s	remaining: 26.7s
# 813:	learn: 0.3926353	total: 1m 56s	remaining: 26.5s
# 814:	learn: 0.3925848	total: 1m 56s	remaining: 26.4s
# 815:	learn: 0.3925608	total: 1m 56s	remaining: 26.2s
# 816:	learn: 0.3925311	total: 1m 56s	remaining: 26.1s
# 817:	learn: 0.3924879	total: 1m 56s	remaining: 26s
# 818:	learn: 0.3924670	total: 1m 56s	remaining: 25.8s
# 819:	learn: 0.3924288	total: 1m 57s	remaining: 25.7s
# 820:	learn: 0.3924081	total: 1m 57s	remaining: 25.5s
# 821:	learn: 0.3923920	total: 1m 57s	remaining: 25.4s
# 822:	learn: 0.3923491	total: 1m 57s	remaining: 25.3s
# 823:	learn: 0.3923056	total: 1m 57s	remaining: 25.1s
# 824:	learn: 0.3922670	total: 1m 57s	remaining: 25s
# 825:	learn: 0.3922544	total: 1m 57s	remaining: 24.8s
# 826:	learn: 0.3921901	total: 1m 58s	remaining: 24.7s
# 827:	learn: 0.3921397	total: 1m 58s	remaining: 24.6s
# 828:	learn: 0.3920928	total: 1m 58s	remaining: 24.4s
# 829:	learn: 0.3920744	total: 1m 58s	remaining: 24.3s
# 830:	learn: 0.3920335	total: 1m 58s	remaining: 24.1s
# 831:	learn: 0.3920168	total: 1m 58s	remaining: 24s
# 832:	learn: 0.3919768	total: 1m 58s	remaining: 23.8s
# 833:	learn: 0.3919554	total: 1m 59s	remaining: 23.7s
# 834:	learn: 0.3919229	total: 1m 59s	remaining: 23.6s
# 835:	learn: 0.3919030	total: 1m 59s	remaining: 23.4s
# 836:	learn: 0.3918802	total: 1m 59s	remaining: 23.3s
# 837:	learn: 0.3918541	total: 1m 59s	remaining: 23.1s
# 838:	learn: 0.3918214	total: 1m 59s	remaining: 23s
# 839:	learn: 0.3917835	total: 1m 59s	remaining: 22.8s
# 840:	learn: 0.3917450	total: 2m	remaining: 22.7s
# 841:	learn: 0.3917155	total: 2m	remaining: 22.5s
# 842:	learn: 0.3916734	total: 2m	remaining: 22.4s
# 843:	learn: 0.3916462	total: 2m	remaining: 22.3s
# 844:	learn: 0.3916194	total: 2m	remaining: 22.1s
# 845:	learn: 0.3915955	total: 2m	remaining: 22s
# 846:	learn: 0.3915740	total: 2m	remaining: 21.8s
# 847:	learn: 0.3915526	total: 2m	remaining: 21.7s
# 848:	learn: 0.3915348	total: 2m 1s	remaining: 21.5s
# 849:	learn: 0.3915079	total: 2m 1s	remaining: 21.4s
# 850:	learn: 0.3914796	total: 2m 1s	remaining: 21.3s
# 851:	learn: 0.3914617	total: 2m 1s	remaining: 21.1s
# 852:	learn: 0.3913906	total: 2m 1s	remaining: 21s
# 853:	learn: 0.3913370	total: 2m 1s	remaining: 20.8s
# 854:	learn: 0.3913042	total: 2m 2s	remaining: 20.7s
# 855:	learn: 0.3912757	total: 2m 2s	remaining: 20.5s
# 856:	learn: 0.3912107	total: 2m 2s	remaining: 20.4s
# 857:	learn: 0.3911908	total: 2m 2s	remaining: 20.3s
# 858:	learn: 0.3911628	total: 2m 2s	remaining: 20.1s
# 859:	learn: 0.3911363	total: 2m 2s	remaining: 20s
# 860:	learn: 0.3911343	total: 2m 2s	remaining: 19.8s
# 861:	learn: 0.3911183	total: 2m 3s	remaining: 19.7s
# 862:	learn: 0.3910839	total: 2m 3s	remaining: 19.6s
# 863:	learn: 0.3910640	total: 2m 3s	remaining: 19.4s
# 864:	learn: 0.3910188	total: 2m 3s	remaining: 19.3s
# 865:	learn: 0.3910009	total: 2m 3s	remaining: 19.1s
# 866:	learn: 0.3909829	total: 2m 4s	remaining: 19s
# 867:	learn: 0.3909771	total: 2m 4s	remaining: 18.9s
# 868:	learn: 0.3909536	total: 2m 4s	remaining: 18.7s
# 869:	learn: 0.3909183	total: 2m 4s	remaining: 18.6s
# 870:	learn: 0.3908880	total: 2m 4s	remaining: 18.5s
# 871:	learn: 0.3908381	total: 2m 4s	remaining: 18.3s
# 872:	learn: 0.3908107	total: 2m 4s	remaining: 18.2s
# 873:	learn: 0.3907474	total: 2m 5s	remaining: 18s
# 874:	learn: 0.3907195	total: 2m 5s	remaining: 17.9s
# 875:	learn: 0.3906150	total: 2m 5s	remaining: 17.8s
# 876:	learn: 0.3905902	total: 2m 5s	remaining: 17.6s
# 877:	learn: 0.3905524	total: 2m 5s	remaining: 17.5s
# 878:	learn: 0.3905027	total: 2m 5s	remaining: 17.3s
# 879:	learn: 0.3904905	total: 2m 5s	remaining: 17.2s
# 880:	learn: 0.3904568	total: 2m 6s	remaining: 17s
# 881:	learn: 0.3904278	total: 2m 6s	remaining: 16.9s
# 882:	learn: 0.3904008	total: 2m 6s	remaining: 16.8s
# 883:	learn: 0.3903704	total: 2m 6s	remaining: 16.6s
# 884:	learn: 0.3903555	total: 2m 6s	remaining: 16.5s
# 885:	learn: 0.3902987	total: 2m 6s	remaining: 16.3s
# 886:	learn: 0.3902758	total: 2m 6s	remaining: 16.2s
# 887:	learn: 0.3902336	total: 2m 7s	remaining: 16s
# 888:	learn: 0.3902226	total: 2m 7s	remaining: 15.9s
# 889:	learn: 0.3901673	total: 2m 7s	remaining: 15.8s
# 890:	learn: 0.3901489	total: 2m 7s	remaining: 15.6s
# 891:	learn: 0.3901206	total: 2m 7s	remaining: 15.5s
# 892:	learn: 0.3900867	total: 2m 7s	remaining: 15.3s
# 893:	learn: 0.3900509	total: 2m 8s	remaining: 15.2s
# 894:	learn: 0.3900037	total: 2m 8s	remaining: 15s
# 895:	learn: 0.3899745	total: 2m 8s	remaining: 14.9s
# 896:	learn: 0.3899570	total: 2m 8s	remaining: 14.8s
# 897:	learn: 0.3899295	total: 2m 8s	remaining: 14.6s
# 898:	learn: 0.3898977	total: 2m 8s	remaining: 14.5s
# 899:	learn: 0.3898727	total: 2m 8s	remaining: 14.3s
# 900:	learn: 0.3898421	total: 2m 9s	remaining: 14.2s
# 901:	learn: 0.3898003	total: 2m 9s	remaining: 14s
# 902:	learn: 0.3897656	total: 2m 9s	remaining: 13.9s
# 903:	learn: 0.3897369	total: 2m 9s	remaining: 13.7s
# 904:	learn: 0.3897026	total: 2m 9s	remaining: 13.6s
# 905:	learn: 0.3896787	total: 2m 9s	remaining: 13.5s
# 906:	learn: 0.3896561	total: 2m 9s	remaining: 13.3s
# 907:	learn: 0.3896146	total: 2m 10s	remaining: 13.2s
# 908:	learn: 0.3895933	total: 2m 10s	remaining: 13s
# 909:	learn: 0.3895810	total: 2m 10s	remaining: 12.9s
# 910:	learn: 0.3895460	total: 2m 10s	remaining: 12.8s
# 911:	learn: 0.3895285	total: 2m 10s	remaining: 12.6s
# 912:	learn: 0.3895028	total: 2m 10s	remaining: 12.5s
# 913:	learn: 0.3894799	total: 2m 10s	remaining: 12.3s
# 914:	learn: 0.3894137	total: 2m 11s	remaining: 12.2s
# 915:	learn: 0.3893909	total: 2m 11s	remaining: 12s
# 916:	learn: 0.3893453	total: 2m 11s	remaining: 11.9s
# 917:	learn: 0.3892976	total: 2m 11s	remaining: 11.7s
# 918:	learn: 0.3892699	total: 2m 11s	remaining: 11.6s
# 919:	learn: 0.3892547	total: 2m 11s	remaining: 11.5s
# 920:	learn: 0.3892137	total: 2m 11s	remaining: 11.3s
# 921:	learn: 0.3892024	total: 2m 12s	remaining: 11.2s
# 922:	learn: 0.3891718	total: 2m 12s	remaining: 11s
# 923:	learn: 0.3891099	total: 2m 12s	remaining: 10.9s
# 924:	learn: 0.3890969	total: 2m 12s	remaining: 10.8s
# 925:	learn: 0.3890732	total: 2m 12s	remaining: 10.6s
# 926:	learn: 0.3890576	total: 2m 12s	remaining: 10.5s
# 927:	learn: 0.3890326	total: 2m 13s	remaining: 10.3s
# 928:	learn: 0.3889984	total: 2m 13s	remaining: 10.2s
# 929:	learn: 0.3889747	total: 2m 13s	remaining: 10s
# 930:	learn: 0.3889571	total: 2m 13s	remaining: 9.89s
# 931:	learn: 0.3889062	total: 2m 13s	remaining: 9.75s
# 932:	learn: 0.3888832	total: 2m 13s	remaining: 9.61s
# 933:	learn: 0.3888629	total: 2m 13s	remaining: 9.46s
# 934:	learn: 0.3888313	total: 2m 14s	remaining: 9.32s
# 935:	learn: 0.3888199	total: 2m 14s	remaining: 9.18s
# 936:	learn: 0.3887985	total: 2m 14s	remaining: 9.03s
# 937:	learn: 0.3887737	total: 2m 14s	remaining: 8.89s
# 938:	learn: 0.3887590	total: 2m 14s	remaining: 8.75s
# 939:	learn: 0.3887275	total: 2m 14s	remaining: 8.6s
# 940:	learn: 0.3887100	total: 2m 14s	remaining: 8.46s
# 941:	learn: 0.3886885	total: 2m 15s	remaining: 8.31s
# 942:	learn: 0.3886660	total: 2m 15s	remaining: 8.17s
# 943:	learn: 0.3886440	total: 2m 15s	remaining: 8.03s
# 944:	learn: 0.3886136	total: 2m 15s	remaining: 7.88s
# 945:	learn: 0.3885940	total: 2m 15s	remaining: 7.74s
# 946:	learn: 0.3885584	total: 2m 15s	remaining: 7.6s
# 947:	learn: 0.3885076	total: 2m 15s	remaining: 7.45s
# 948:	learn: 0.3884795	total: 2m 16s	remaining: 7.31s
# 949:	learn: 0.3884554	total: 2m 16s	remaining: 7.17s
# 950:	learn: 0.3884058	total: 2m 16s	remaining: 7.03s
# 951:	learn: 0.3883709	total: 2m 16s	remaining: 6.88s
# 952:	learn: 0.3883381	total: 2m 16s	remaining: 6.74s
# 953:	learn: 0.3883139	total: 2m 16s	remaining: 6.59s
# 954:	learn: 0.3882876	total: 2m 16s	remaining: 6.45s
# 955:	learn: 0.3882690	total: 2m 17s	remaining: 6.31s
# 956:	learn: 0.3882490	total: 2m 17s	remaining: 6.16s
# 957:	learn: 0.3881996	total: 2m 17s	remaining: 6.02s
# 958:	learn: 0.3881488	total: 2m 17s	remaining: 5.88s
# 959:	learn: 0.3881199	total: 2m 17s	remaining: 5.73s
# 960:	learn: 0.3880950	total: 2m 17s	remaining: 5.59s
# 961:	learn: 0.3880576	total: 2m 17s	remaining: 5.45s
# 962:	learn: 0.3879748	total: 2m 18s	remaining: 5.3s
# 963:	learn: 0.3879291	total: 2m 18s	remaining: 5.16s
# 964:	learn: 0.3878940	total: 2m 18s	remaining: 5.02s
# 965:	learn: 0.3878734	total: 2m 18s	remaining: 4.87s
# 966:	learn: 0.3878382	total: 2m 18s	remaining: 4.73s
# 967:	learn: 0.3877808	total: 2m 18s	remaining: 4.59s
# 968:	learn: 0.3877384	total: 2m 18s	remaining: 4.44s
# 969:	learn: 0.3877183	total: 2m 19s	remaining: 4.3s
# 970:	learn: 0.3877009	total: 2m 19s	remaining: 4.16s
# 971:	learn: 0.3876505	total: 2m 19s	remaining: 4.01s
# 972:	learn: 0.3876304	total: 2m 19s	remaining: 3.87s
# 973:	learn: 0.3876053	total: 2m 19s	remaining: 3.73s
# 974:	learn: 0.3875777	total: 2m 19s	remaining: 3.58s
# 975:	learn: 0.3875507	total: 2m 19s	remaining: 3.44s
# 976:	learn: 0.3875353	total: 2m 20s	remaining: 3.3s
# 977:	learn: 0.3875233	total: 2m 20s	remaining: 3.15s
# 978:	learn: 0.3874932	total: 2m 20s	remaining: 3.01s
# 979:	learn: 0.3874626	total: 2m 20s	remaining: 2.87s
# 980:	learn: 0.3874077	total: 2m 20s	remaining: 2.72s
# 981:	learn: 0.3873872	total: 2m 20s	remaining: 2.58s
# 982:	learn: 0.3873575	total: 2m 20s	remaining: 2.44s
# 983:	learn: 0.3873256	total: 2m 21s	remaining: 2.29s
# 984:	learn: 0.3873105	total: 2m 21s	remaining: 2.15s
# 985:	learn: 0.3872744	total: 2m 21s	remaining: 2.01s
# 986:	learn: 0.3872310	total: 2m 21s	remaining: 1.86s
# 987:	learn: 0.3871897	total: 2m 21s	remaining: 1.72s
# 988:	learn: 0.3871499	total: 2m 21s	remaining: 1.58s
# 989:	learn: 0.3871150	total: 2m 21s	remaining: 1.43s
# 990:	learn: 0.3870679	total: 2m 21s	remaining: 1.29s
# 991:	learn: 0.3870578	total: 2m 22s	remaining: 1.15s
# 992:	learn: 0.3870371	total: 2m 22s	remaining: 1s
# 993:	learn: 0.3870166	total: 2m 22s	remaining: 860ms
# 994:	learn: 0.3869638	total: 2m 22s	remaining: 716ms
# 995:	learn: 0.3869513	total: 2m 22s	remaining: 573ms
# 996:	learn: 0.3869415	total: 2m 22s	remaining: 430ms
# 997:	learn: 0.3869222	total: 2m 23s	remaining: 287ms
# 998:	learn: 0.3868923	total: 2m 23s	remaining: 143ms
# 999:	learn: 0.3868724	total: 2m 23s	remaining: 0us

# %%
roc_auc_score(y_valid, cat_model.predict_proba(X_valid)[:, 1])
# Out:
# 0.7643552172108752

# %% [markdown]
# ## DBSCAN своими руками (2 + 2* баллов)

# %% [markdown]
# DBSCAN: Density-based spatial clustering of applications with noise
#
# Реализуйте класс dbscan.
#
# Алгоритм имеет два основных гиперпараметра:
# 1. `eps` &mdash; радиус рассматриваемой окрестности
# 2. `min_samples` &mdash; число соседей в окрестности
#
# Для выполнения кластеризации DBSCAN точки делятся на основные точки, достижимые по плотности точки и выпадающие следующим образом:
#
# - Точка $p$ является основной точкой, если по меньшей мере `min_samples` точек находятся на расстоянии, не превосходящем
# `eps` от неё. Говорят, что эти точки достижимы прямо из $p$.
#
# -  Точка $q$ прямо достижима из $p$, если точка $q$ находится на расстоянии, не большем `eps`, от точки $p$, и $p$ — основная точка.
# Точка $q$ достижима из $p$, если имеется путь
# $p_1,…,p_n$ где $p_1=p$ и $p_n=q$ , а каждая точка $p_{i+1}$ достижима прямо из $p_i$ (все точки на пути должны быть основными, за исключением $q$).
#
# Все точки, не достижимые из основных точек, считаются выбросами.
#
# Теперь, если $p$ является основной точкой, то она формирует кластер вместе со всеми точками (основными или неосновными), достижимыми из этой точки. Каждый кластер содержит по меньшей мере одну основную точку. Неосновные точки могут быть частью кластера, но они формируют его «край», поскольку не могут быть использованы для достижения других точек.

# %%
# Это может помочь вам для поиска дистанции между точками
from scipy.spatial import distance

# %%
# Рекомендации -- это только рекомендации
class dbscan:
    def __init__(self, eps, min_samples):
        # your code here
        self.eps = eps
        self.min_samples = min_samples
        
    def fit_predict(self, X):
        self.X = X
        self.k = 0
        self.d = np.zeros(len(X))
        for i in range(len(X)):
            if self.d[i] == 0:
                neighbours = self.range_query(i)
                if len(neighbours) < self.min_samples:
                    self.d[i] = -1
                else:
                    self.k += 1
                    self.grow_cluster(i, neighbours)
        return self.d

    def grow_cluster(self, root, neighbours):
        k = self.k
        self.d[root] = k
        j = 0
        while (j < len(neighbours)):
            i = neighbours[j]
            if self.d[i] <= 0:
                self.d[i] = k
                neighbours2 = self.range_query(i)
                if len(neighbours2) >= self.min_samples:
                    neighbours = np.concatenate((neighbours, neighbours2), axis=0)
            j += 1

    def range_query(self, i):
        """Возвращает точки на расстоянии <= eps от X[i]"""
        ans = []
        x = self.X[i]
        for i in range(len(X)):
            t = self.X[i]
            if self.dist(t, x) <= self.eps:
                ans.append(i)
        return np.array(ans)
        
    
    @staticmethod
    def dist(a, b):
        """Метрика расстояния"""
        # Попробуйте что-нибудь из scipy.spatial.distance
        # Базовый вариант -- Евклидова метрика
        # your code here
        return np.linalg.norm(a-b)

# %% [markdown]
# Проверим себя на простом примере:

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import pandas as pd

X, _ = make_moons(n_samples=500, noise=0.1)
plt.scatter(X[:,0], X[:,1])
plt.show()

# %% [markdown]
# Кластеризуйте это с помощью своей версии DBSCAN:

# %%
clusters = dbscan(eps=0.2, min_samples=10).fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=clusters)
plt.show()

# %% [markdown]
# Референс:

# %%
from sklearn.cluster import DBSCAN

clusters = DBSCAN(eps=0.2, min_samples=10).fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=clusters)
plt.show()

# %% [markdown]
# Получите 1 балл за ещё один интересный пример кластеризации (в качестве референса используйте предоставленное изображение. Нужно несколько интересных соседствующих форм):

# %%
from sklearn.datasets import make_blobs
from sklearn.datasets import make_circles
plt.figure(figsize=(16, 6))
X1, _ = make_circles(n_samples=1000, factor=0.5, noise=0.02)
transformation = [[6, 0], [0, 6]]
X1 = np.dot(X1, transformation)
X2, _ = make_moons(n_samples=200, noise=0.01)
transformation = [[2, 0], [0, 2]]
X2 = X2**2 - [3, 4]
X3, _ = make_moons(n_samples=200, noise=0.02)
transformation = [[1.3, 0], [0, 1.3]]
X3 = np.dot(X3, transformation) - 0.5
X4, _ = make_blobs(n_samples=200, centers=2, random_state=178)
transformation = [[1/5, 0], [0, 1/5]]
X4 = np.dot(X4, transformation)+[-4.6, 2]
X = np.concatenate((X1, X2, X3, X4), axis=0)
transformation = [[1/2.5, 0], [0, 1/2.5]]
X = np.dot(X, transformation)
plt.scatter(X[:,0], X[:,1])
plt.axis('equal') 
plt.show()

# %%
clusters = dbscan(eps=0.2, min_samples=10).fit_predict(X)

plt.scatter(X[:,0], X[:,1], c=clusters)
plt.axis('equal') 
plt.show()

# %% [markdown]
# Или хотя бы что-нибудь такое:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Получите ещё 1 балл, если время работы вашего алгоритма больше референсного не более чем в 100 раз с учётом погрешности 3% от вашего времени:

# %%
# %%time
# %%capture
clusters = DBSCAN(eps=0.2, min_samples=10).fit_predict(X)
# Out:
# Wall time: 38.7 ms

# %%
# %%time
# %%capture
clusters = dbscan(eps=0.2, min_samples=10).fit_predict(X)
# Out:
# Wall time: 37.2 s
